# %% [markdown]
# # Working with datetime in Pandas DataFrame
#
# This is a notebook for the medium article [Working with datetime in Pandas DataFrame](https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587)
#
# Please check out article for instructions
#
# **License**: [BSD 2-Clause](https://opensource.org/licenses/BSD-2-Clause)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Convert strings to datetime

# %% [markdown]
# #### Default arguments

# %%
df = pd.DataFrame({'date': ['3/10/2000', '3/11/2000', '3/12/2000'],
                   'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#         date  value
# 0 2000-03-10      2
# 1 2000-03-11      3
# 2 2000-03-12      4

# %% [markdown]
# #### Day first format

# %%
df = pd.DataFrame({'date': ['3/10/2000', '3/11/2000', '3/12/2000'],
                   'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

# %%
df
# Out:
#         date  value
# 0 2000-10-03      2
# 1 2000-11-03      3
# 2 2000-12-03      4

# %% [markdown]
# #### Custom format

# %%
df = pd.DataFrame({'date': ['2016-6-10 20:30:0', 
                            '2016-7-1 19:45:30', 
                            '2013-10-12 4:5:1'],
                   'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'], format="%Y-%d-%m %H:%M:%S")

# %%
df
# Out:
#                  date  value
# 0 2016-10-06 20:30:00      2
# 1 2016-01-07 19:45:30      3
# 2 2013-12-10 04:05:01      4

# %% [markdown]
# #### Speedup parsing with infer_datetime_format

# %%
df = pd.DataFrame({'date': ['3/11/2000', '3/12/2000', '3/13/2000'] * 1000 })
df.head()
# Out:
#         date
# 0  3/11/2000
# 1  3/12/2000
# 2  3/13/2000
# 3  3/11/2000
# 4  3/12/2000

# %%
# %timeit pd.to_datetime(df['date'], infer_datetime_format=True)
# Out:
# 1.82 ms ± 58.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit pd.to_datetime(df['date'], infer_datetime_format=False)
# Out:
# 1.69 ms ± 83.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# #### Handle parsing error

# %%
df = pd.DataFrame({'date': ['3/10/2000', 'a/11/2000', '3/12/2000'],
                   'value': [2, 3, 4]})
df['date'] = pd.to_datetime(df['date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# c:\Work\Ref\machine-learning\data-analysis\008-pandas-datetime\pandas-datetime.ipynb Cell 18 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Work/Ref/machine-learning/data-analysis/008-pandas-datetime/pandas-datetime.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame({'date': ['3/10/2000', 'a/11/2000', '3/12/2000'],
#       <a href='vscode-notebook-cell:/c%3A/Work/Ref/machine-learning/data-analysis/008-pandas-datetime/pandas-datetime.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>                    'value': [2, 3, 4]})
# ----> <a href='vscode-notebook-cell:/c%3A/Work/Ref/machine-learning/data-analysis/008-pandas-datetime/pandas-datetime.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> df['date'] = pd.to_datetime(df['date'])
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\core\tools\datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\core\arrays\datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\core\arrays\datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\Users\10696\Anaconda3\envs\jg\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: a/11/2000

# %%
df['date'] = pd.to_datetime(df['date'], errors='ignore')
df
# Out:
#         date  value
# 0  3/10/2000      2
# 1  a/11/2000      3
# 2  3/12/2000      4

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')
df
# Out:
#         date  value
# 0 2000-03-10      2
# 1        NaT      3
# 2 2000-03-12      4

# %% [markdown]
# ### 2. Assemble a datetime from multiple columns

# %%
df = pd.DataFrame({'year': [2015, 2016],
                   'month': [2, 3],
                   'day': [4, 5]})

df['date'] = pd.to_datetime(df)

# %%
df
# Out:
#    year  month  day       date
# 0  2015      2    4 2015-02-04
# 1  2016      3    5 2016-03-05

# %% [markdown]
# ### 3. Get year, month and day

# %%
df = pd.DataFrame({'name': ['Tom', 'Andy', 'Lucas'],
                 'DoB': ['08-05-1997', '04-28-1996', '12-16-1995']})
df['DoB'] = pd.to_datetime(df['DoB'])

# %%
df['year']= df['DoB'].dt.year
df['month']= df['DoB'].dt.month
df['day']= df['DoB'].dt.day
df
# Out:
#     name        DoB  year  month  day
# 0    Tom 1997-08-05  1997      8    5
# 1   Andy 1996-04-28  1996      4   28
# 2  Lucas 1995-12-16  1995     12   16

# %% [markdown]
# ### 4. Get the week of year, the day of week and leap year

# %%
# df['week_of_year'] = df['DoB'].dt.week
df['week_of_year'] = df['DoB'].dt.isocalendar().week
df['day_of_week'] = df['DoB'].dt.dayofweek
df['is_leap_year'] = df['DoB'].dt.is_leap_year
df
# Out:
#     name        DoB  year  month  day  week_of_year  day_of_week  is_leap_year
# 0    Tom 1997-08-05  1997      8    5            32            1         False
# 1   Andy 1996-04-28  1996      4   28            17            6          True
# 2  Lucas 1995-12-16  1995     12   16            50            5         False

# %%
dw_mapping={
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
} 
df['day_of_week_name']=df['DoB'].dt.weekday.map(dw_mapping)
df
# Out:
#     name        DoB  year  month  day  week_of_year  day_of_week  \
# 0    Tom 1997-08-05  1997      8    5            32            1
# 1   Andy 1996-04-28  1996      4   28            17            6
# 2  Lucas 1995-12-16  1995     12   16            50            5
#
#    is_leap_year day_of_week_name
# 0         False          Tuesday
# 1          True           Sunday
# 2         False         Saturday

# %% [markdown]
# ### 5. Get the age from the date of birth

# %%
today = pd.to_datetime('today')
df['age'] = today.year - df['DoB'].dt.year

df
# Out:
#     name        DoB  year  month  day  week_of_year  day_of_week  \
# 0    Tom 1997-08-05  1997      8    5            32            1
# 1   Andy 1996-04-28  1996      4   28            17            6
# 2  Lucas 1995-12-16  1995     12   16            50            5
#
#    is_leap_year day_of_week_name  age
# 0         False          Tuesday   23
# 1          True           Sunday   24
# 2         False         Saturday   25

# %%
# Year difference
today = pd.to_datetime('today')
diff_y = today.year - df['DoB'].dt.year
# Haven't had birthday
b_md = df['DoB'].apply(lambda x: (x.month,x.day) )
no_birthday = b_md > (today.month,today.day)

df['age'] = diff_y - no_birthday
df
# Out:
#     name        DoB  year  month  day  week_of_year  day_of_week  \
# 0    Tom 1997-08-05  1997      8    5            32            1
# 1   Andy 1996-04-28  1996      4   28            17            6
# 2  Lucas 1995-12-16  1995     12   16            50            5
#
#    is_leap_year day_of_week_name  age
# 0         False          Tuesday   23
# 1          True           Sunday   24
# 2         False         Saturday   24

# %% [markdown]
# ### 6. Improve performance by setting date column as the index

# %%
df = pd.read_csv('data/city_sales.csv',parse_dates=['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795144 entries, 0 to 1795143
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   num     int64
#  2   city    object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 41.1+ MB

# %%
df = df.set_index(['date'])

# %%
df
# Out:
#                      num       city
# date
# 2015-01-01 09:00:00    4     London
# 2015-01-01 09:01:00    4     London
# 2015-01-01 09:02:00    3     London
# 2015-01-01 09:03:00    3     London
# 2015-01-01 09:04:00    3     London
# ...                  ...        ...
# 2019-01-31 15:56:00    3  Cambridge
# 2019-01-31 15:57:00    3  Cambridge
# 2019-01-31 15:58:00    3  Cambridge
# 2019-01-31 15:59:00    3  Cambridge
# 2019-01-31 16:00:00    2  Cambridge
#
# [1795144 rows x 2 columns]

# %% [markdown]
# ### 7. Select data with a specific year and perform aggregation

# %%
df.loc['2018']
# Out:
#                      num       city
# date
# 2018-01-01 09:00:00    2     London
# 2018-01-01 09:01:00    1     London
# 2018-01-01 09:02:00    3     London
# 2018-01-01 09:03:00    3     London
# 2018-01-01 09:04:00    3     London
# ...                  ...        ...
# 2018-12-31 15:56:00    4  Cambridge
# 2018-12-31 15:57:00    2  Cambridge
# 2018-12-31 15:58:00    3  Cambridge
# 2018-12-31 15:59:00    3  Cambridge
# 2018-12-31 16:00:00    2  Cambridge
#
# [439524 rows x 2 columns]

# %%
df.loc['2018','num'].sum()
# Out:
# 1231190

# %%
# df['2018'].groupby('city').sum()
df.loc['2018'].groupby('city').sum()
# Out:
#               num
# city
# Cambridge  308428
# Durham     307965
# London     307431
# Oxford     307366

# %% [markdown]
# ### 8. Select data with a specific month or a specific day of the month

# %%
df.loc['2018-5']
# Out:
#                      num       city
# date
# 2018-05-01 09:00:00    1     London
# 2018-05-01 09:01:00    4     London
# 2018-05-01 09:02:00    3     London
# 2018-05-01 09:03:00    2     London
# 2018-05-01 09:04:00    3     London
# ...                  ...        ...
# 2018-05-31 15:56:00    3  Cambridge
# 2018-05-31 15:57:00    4  Cambridge
# 2018-05-31 15:58:00    2  Cambridge
# 2018-05-31 15:59:00    3  Cambridge
# 2018-05-31 16:00:00    3  Cambridge
#
# [38732 rows x 2 columns]

# %%
df.loc['2018-05-1']
# Out:
#                      num       city
# date
# 2018-05-01 09:00:00    1     London
# 2018-05-01 09:01:00    4     London
# 2018-05-01 09:02:00    3     London
# 2018-05-01 09:03:00    2     London
# 2018-05-01 09:04:00    3     London
# ...                  ...        ...
# 2018-05-01 15:56:00    2  Cambridge
# 2018-05-01 15:57:00    3  Cambridge
# 2018-05-01 15:58:00    3  Cambridge
# 2018-05-01 15:59:00    3  Cambridge
# 2018-05-01 16:00:00    1  Cambridge
#
# [1684 rows x 2 columns]

# %%
cond = df.index.month==2
df[cond]
# Out:
#                      num       city
# date
# 2015-02-02 09:00:00    4     London
# 2015-02-02 09:01:00    3     London
# 2015-02-02 09:02:00    3     London
# 2015-02-02 09:03:00    2     London
# 2015-02-02 09:04:00    1     London
# ...                  ...        ...
# 2018-02-28 15:56:00    4  Cambridge
# 2018-02-28 15:57:00    3  Cambridge
# 2018-02-28 15:58:00    4  Cambridge
# 2018-02-28 15:59:00    4  Cambridge
# 2018-02-28 16:00:00    4  Cambridge
#
# [136404 rows x 2 columns]

# %% [markdown]
# ### 9. Select data between two dates

# %%
df.loc['2016' : '2018']
# Out:
# C:\Users\10696\AppData\Local\Temp\ipykernel_7788\380412996.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   df.loc['2016' : '2018']
#                      num       city
# date
# 2016-01-01 09:00:00    4     London
# 2016-01-01 09:01:00    3     London
# 2016-01-01 09:02:00    4     London
# 2016-01-01 09:03:00    4     London
# 2016-01-01 09:04:00    2     London
# ...                  ...        ...
# 2018-12-31 15:56:00    4  Cambridge
# 2018-12-31 15:57:00    2  Cambridge
# 2018-12-31 15:58:00    3  Cambridge
# 2018-12-31 15:59:00    3  Cambridge
# 2018-12-31 16:00:00    2  Cambridge
#
# [1316888 rows x 2 columns]

# %%
df.loc['2018-5-2 10' : '2018-5-2 11' ]
# Out:
#                      num       city
# date
# 2018-05-02 10:00:00    2     London
# 2018-05-02 10:01:00    3     London
# 2018-05-02 10:02:00    4     London
# 2018-05-02 10:03:00    4     London
# 2018-05-02 10:04:00    4     London
# ...                  ...        ...
# 2018-05-02 11:55:00    3  Cambridge
# 2018-05-02 11:56:00    3  Cambridge
# 2018-05-02 11:57:00    4  Cambridge
# 2018-05-02 11:58:00    4  Cambridge
# 2018-05-02 11:59:00    1  Cambridge
#
# [480 rows x 2 columns]

# %%
df.loc['2018-5-2 10:30' : '2018-5-2 10:45' ]
# Out:
#                      num       city
# date
# 2018-05-02 10:30:00    3     London
# 2018-05-02 10:31:00    3     London
# 2018-05-02 10:32:00    1     London
# 2018-05-02 10:33:00    3     London
# 2018-05-02 10:34:00    3     London
# ...                  ...        ...
# 2018-05-02 10:41:00    3  Cambridge
# 2018-05-02 10:42:00    3  Cambridge
# 2018-05-02 10:43:00    3  Cambridge
# 2018-05-02 10:44:00    3  Cambridge
# 2018-05-02 10:45:00    1  Cambridge
#
# [64 rows x 2 columns]

# %%
df.between_time('10:30','10:45')
# Out:
#                      num       city
# date
# 2015-01-01 10:30:00    4     London
# 2015-01-01 10:31:00    3     London
# 2015-01-01 10:32:00    3     London
# 2015-01-01 10:33:00    3     London
# 2015-01-01 10:34:00    4     London
# ...                  ...        ...
# 2019-01-31 10:41:00    3  Cambridge
# 2019-01-31 10:42:00    3  Cambridge
# 2019-01-31 10:43:00    1  Cambridge
# 2019-01-31 10:44:00    3  Cambridge
# 2019-01-31 10:45:00    4  Cambridge
#
# [68224 rows x 2 columns]

# %% [markdown]
# ### 10. Handle missing values

# %%
# df['rolling_sum'] = df.rolling(3).sum()
df['rolling_sum'] = df['num'].rolling(3).sum()
df.head()
# Out:
#                      num    city  rolling_sum
# date
# 2015-01-01 09:00:00    4  London          NaN
# 2015-01-01 09:01:00    4  London          NaN
# 2015-01-01 09:02:00    3  London         11.0
# 2015-01-01 09:03:00    3  London         10.0
# 2015-01-01 09:04:00    3  London          9.0

# %%
df['rolling_sum_backfilled'] = df['rolling_sum'].fillna(method='backfill')
df.head()
# Out:
#                      num    city  rolling_sum  rolling_sum_backfilled
# date
# 2015-01-01 09:00:00    4  London          NaN                    11.0
# 2015-01-01 09:01:00    4  London          NaN                    11.0
# 2015-01-01 09:02:00    3  London         11.0                    11.0
# 2015-01-01 09:03:00    3  London         10.0                    10.0
# 2015-01-01 09:04:00    3  London          9.0                     9.0

# %% [markdown]
# ### That's it
# This is a notebook for the medium article [Working with datetime in Pandas DataFrame](https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587)
#
# Please check out article for instructions
